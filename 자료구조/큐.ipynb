# %% [markdown]
# #큐
# FIFO = first in first out
#
# 규칙의 순차적 자료구조
#
# ||stack|queue|
# |------|---|---|
# |insert|push|enqueue|
# |delete|pop|dequeue|

# %% [markdown]
# ![제목 없음.png](data:image/png;base64,...)

# %% [markdown]
# ```
# class queue:
#   def __int__(self):
#     #빈 리스트로 초기화
#     self.items = []
#     self.front_index = 0
#
#   def enqueue(self,val):
#     self.items.append(val)
#
#   def dequeue(self):
#     if self.front_index == len(self.items):
#       print("q" is empty)
#
#   #위의 그림을 볼때 큐 내부에 5와 -2가 존재한다.
#   #이때 len(self.items)의 크기는 2다.
#   #그리고 우리는 self.front_index = 0 으로 정의했다.
#   #하지만 이때 위 그림처럼 모두 다 dequeue를 진행하면 다시
#   # 큐의 len은 0이다.
#   #즉 self.front_index == len(self.items)는 아무것도 없는
#   #경우를 의미한다.
#
#     else:
#       x = self.items[front_index]
#       self.front_index += 1
#       reutrn x
#
#   # 만일 큐 내부에 요소가 존재한다면
#   #x = self.items[front_index]를 통해서 받는다.
#   #그리고 return을 통해 답을 도출한다.
#   #그리고 self.front_index += 1을 하는 이유는
#   #front_index값을 dequeue했기때문에 다음 순서로
#   #front_index를 넘겨야 하기 때문이다.
# ```
