# %% [markdown]
# #순차적 자료 구조

# %% [markdown]
# ##1. 배열과 리스트
# -인덱스로 임의의 원소를 접근
#
# A = [3,2,-1,5,7]
#
# 연산자 ---> A[0] = 3 시간복잡도 O(1)
#
# 삽입 (append, insert)
#
# 삭제 (pop, remove)

# %% [markdown]
# ##2. stack
# - 제한된 접근(삽입, 삭제)
#
# - stack------> lifo(last in first out)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##3. queue
# queue = fifo(first in frist out)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##4. dequeue
# stack + queue
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##5. 연결리스트
# 파이썬의 리스트와 다른것
#
# 다음값에 대한 주소를 저장하고 있다.
#
# ![image.png](data:image/png;base64,...)
